# %% [markdown]
# # 대구시 중구 10년치 매매거래와 거래된 아파트의 세부정보를 얻기위한 코드

# %% [markdown]
# 데이터는 https://www.data.go.kr 여기에서 API를 사용해서 받았습니다

# %% [markdown]
# 필요한 라이브러리 준비

# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
from dateutil.rrule import rrule, MONTHLY
import csv
import sys
import numpy as np
import json

# %% [markdown]
# # Get Data

# %%
'''
    Get data using API and save to csv file.
'''

deal_ymd = []
data_column = ['거래금액', '건축년도', '년', '법정동', '아파트', '월', '일', '전용면적', '지번', '지역코드', '층']

# 10년치 데이터를 얻기위해 년도와 월을 만들기위한 함수
def month_iter(start_year, start_month, end_year, end_month):
    start = datetime(start_year, start_month, 1)
    end = datetime(end_year, end_month, 1)

    for d in rrule(MONTHLY, dtstart=start, until=end):
        deal_ymd.append(str(d.year) + str(month_printer(d)))

# 월 변환 함수
def month_printer(dateObj):
    if dateObj.month < 10:
        return '0' + str(dateObj.month)
    else:
        return dateObj.month

# 2007년 8월 ~ 2017년 8월 까지의 데이터
month_iter(2007, 8, 2017, 8)

# 받은 데이터를 csv파일로 저장
with open('jib.csv', "w", newline='') as csv_file:
        writer = csv.writer(csv_file, delimiter=',')
        # write header
        writer.writerow(data_column)
        
        # 키 값은 https://www.data.go.kr 여기에 들어가서 자료신청을 하면 개인별 고유키값을 줍니다.
        # 키 값 2007.8 ~ 2017.8
        for d in deal_ymd:
            key = '&serviceKey=뭐라뭐라~~ 자기 키값넣으시면됩니다.'
            URL = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?LAWD_CD=27110&DEAL_YMD=' + d + key
            res = urllib.request.urlopen(URL)
            # xml포맷을 파싱
            soup = BeautifulSoup(res, "xml")
            # 페이지에 있는 모든 아이템을 찾는다.
            items = soup.find_all("item")

            # 아이템들을 순회하면서
            # 그 안에 태그안 데이터들을 리스트에 붙여넣습니다.
            # 그렇게 하나의 데이터가 끝나면 csv에 쓰고 다음 데이터로
            for item in items:
                deal = []
                deal.append(item.find("거래금액").text)
                deal.append(item.find("건축년도").text)
                deal.append(item.find("년").text)
                deal.append(item.find("법정동").text)
                deal.append(item.find("아파트").text)
                deal.append(item.find("월").text)
                deal.append(item.find("일").text)
                deal.append(item.find("전용면적").text)
                deal.append(item.find("지번").text)
                deal.append(item.find("지역코드").text)
                deal.append(item.find("층").text)
                writer.writerow(deal)

# %%
# 저장한 데이터를 테이블로 읽어옵니다.
df = pd.read_csv('jib.csv')
df.head(10)
# Out:
#          거래금액  건축년도     년     법정동     아파트  월      일    전용면적     지번   지역코드   층
# 0      14,500  2007  2007   동인동1가  삼승슈퍼타워  8   1~10   83.50    362  27110   7
# 1      15,300  2007  2007   동인동1가  삼승슈퍼타워  8  21~31   83.50    362  27110  14
# 2      16,920  2007  2007   동인동1가  삼승슈퍼타워  8  21~31   83.50    362  27110  11
# 3      16,000  2006  2007     봉산동   봉산뜨란채  8   1~10   75.95    110  27110   3
# 4       9,200  1975  2007      수동    희도맨션  8   1~10  101.26    101  27110   8
# 5       5,800  1985  2007   태평로1가   태평라이프  8   1~10   54.60  1-187  27110   8
# 6       5,500  1985  2007   태평로1가   태평라이프  8   1~10   54.60  1-187  27110   6
# 7       5,100  1976  2007     도원동      도원  8   1~10   38.91    3-5  27110   2
# 8      12,500  2007  2007     동산동  석우리치타운  8   1~10   81.90    5-2  27110   4
# 9      12,500  2007  2007     동산동  석우리치타운  8  11~20   81.90    5-2  27110   3

# %% [markdown]
# #### 거래금액은 기본단위가 만원

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6926 entries, 0 to 6925
# Data columns (total 11 columns):
# 거래금액    6926 non-null object
# 건축년도    6926 non-null int64
# 년       6926 non-null int64
# 법정동     6926 non-null object
# 아파트     6926 non-null object
# 월       6926 non-null int64
# 일       6926 non-null object
# 전용면적    6926 non-null float64
# 지번      6926 non-null object
# 지역코드    6926 non-null int64
# 층       6926 non-null int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 595.3+ KB

# %% [markdown]
# # 데이터 만지기

# %% [markdown]
# ## 데이터에 대해 3가지를 따져봐야합니다.
# 1. null value 가 데이터 안에 있는지
# 2. 각 데이터들에(문자열) 공백이 있는지
# 3. 데이터 형이 적절한지

# %%
# 데이터 안에 공백이 있는지 쉽게 알기위해 numpy 리스트로 읽고 랜덤으로 아무거나 하나 봅니다.

# 파일읽기
with open('jib.csv', newline='') as f:
    reader = csv.reader(f, delimiter=',')
    deal_data = [row for row in reader]
# 리스트를 numpy array 로 변환.
deal_data = np.array(deal_data)

# 아무거나 하나 선택해서 보기
print(deal_data[124])
# Out:
# ['     9,250' '1992' '2007' ' 남산동' '송림맨션' '11' '21~30' '59.99' '2434'
#  '27110' '16']

# %% [markdown]
# 거래금액과 법정동에 공백이 있네요. 고쳐봅시다

# %% [markdown]
# 그리고 거래금액의 경우 우리가 예측하려는 타겟변수입니다. 꼭 int나 float 숫자형으로 바꿔줘야합니다.

# %%
# null 이 있는지 확인
df.isnull().sum()
# Out:
# 거래금액    0
# 건축년도    0
# 년       0
# 법정동     0
# 아파트     0
# 월       0
# 일       0
# 전용면적    0
# 지번      0
# 지역코드    0
# 층       0
# dtype: int64

# %%
# 거래금액 데이터를 문자열에서 숫자로 바꿔줘야 합니다.
# 일단 strip()으로 공백을 제거후,
# replace()로 데이터 내의 콤마를 없애줍니다.
# 그리고 자료형을 숫자형으로 변환

df['거래금액'] = df['거래금액'].apply(lambda x: int(x.strip().replace(',', '')))
df['거래금액'][:5]
# Out:
# 0    14500
# 1    15300
# 2    16920
# 3    16000
# 4     9200
# Name: 거래금액, dtype: int64

# %% [markdown]
# 잘 됬네요.

# %%
# 법정동데이터에 공백을 없애줍니다.
df['법정동'] = df['법정동'].apply(lambda x: x.strip())

# %%
# set을 이용해 법정동안에 있는 값들을 얻습니다. 
dong_list = set(df['법정동'])

# set을 리스트로 변환
dong_list = list(dong_list)
dong_list
# Out:
# ['동산동',
#  '수동',
#  '수창동',
#  '장관동',
#  '태평로2가',
#  '계산동2가',
#  '교동',
#  '삼덕동2가',
#  '동인동3가',
#  '도원동',
#  '남산동',
#  '동인동4가',
#  '시장북로',
#  '삼덕동3가',
#  '대봉동',
#  '달성동',
#  '태평로1가',
#  '서성로1가',
#  '봉산동',
#  '대신동',
#  '태평로3가',
#  '동인동1가']

# %% [markdown]
# 끝!

# %%
# 아파트코드를 받아오기 위해서는 loadcode;법정동코드를 알아야한다.
# 직접 code.go.kr에서 중구 전체의 동을 엑셀파일로 받아옴
# 받은 파일을 읽어와서 실거래 데이터에 포함된 동들을 찾아 코드 저장

dong_code_df = pd.read_excel('junggu_dongcode.xls')
dong_code_df.head(10)
# Out:
#         법정동코드            법정동명
# 0  2711000000        대구광역시 중구
# 1  2711010100  대구광역시 중구 동인동1가
# 2  2711010200  대구광역시 중구 동인동2가
# 3  2711010300  대구광역시 중구 동인동3가
# 4  2711010400  대구광역시 중구 동인동4가
# 5  2711010500  대구광역시 중구 삼덕동1가
# 6  2711010600  대구광역시 중구 삼덕동2가
# 7  2711010700  대구광역시 중구 삼덕동3가
# 8  2711010800    대구광역시 중구 봉산동
# 9  2711010900    대구광역시 중구 장관동

# %%
# dong_code_df에서 첫번째 행은 동에대한 정보가 없으므로 삭제합니다.
dong_code_df.drop(dong_code_df.index[0], inplace=True)

# %%
# 우리가 원하는 것은 법정동이므로
# 법정동명을 공백으로 나누면 ex. 대구광역시 중구 동인동1가 --> [대구광역시, 중구, 동인동1가] 이렇게 3개로 나뉩니다.
# 이중 마지막것이 우리가 원하는 동이름이므로 3번째 것으로 다시 저장합니다.

dong_code_df['법정동명'] = dong_code_df['법정동명'].apply(lambda x: x.split()[2])

# %%
dong_code_df
# Out:
#          법정동코드   법정동명
# 1   2711010100  동인동1가
# 2   2711010200  동인동2가
# 3   2711010300  동인동3가
# 4   2711010400  동인동4가
# 5   2711010500  삼덕동1가
# 6   2711010600  삼덕동2가
# 7   2711010700  삼덕동3가
# 8   2711010800    봉산동
# 9   2711010900    장관동
# 10  2711011000    상서동
# 11  2711011100     수동
# 12  2711011200    덕산동
# 13  2711011300   종로1가
# 14  2711011400   종로2가
# 15  2711011500    사일동
# 16  2711011600    동일동
# 17  2711011700    남일동
# 18  2711011800     전동
# 19  2711011900  동성로3가
# 20  2711012000    동문동
# 21  2711012100    문화동
# 22  2711012200    공평동
# 23  2711012300  동성로2가
# 24  2711012400  태평로1가
# 25  2711012500     교동
# 26  2711012600    용덕동
# 27  2711012700    상덕동
# 28  2711012800    완전동
# 29  2711012900    도원동
# 30  2711013000    수창동
# 31  2711013100  태평로3가
# 32  2711013200    인교동
# 33  2711013300    서야동
# 34  2711013400  서성로1가
# 35  2711013500   시장북로
# 36  2711013600    하서동
# 37  2711013700    남성로
# 38  2711013800  계산동1가
# 39  2711013900  계산동2가
# 40  2711014000    동산동
# 41  2711014100  서문로2가
# 42  2711014200  서성로2가
# 43  2711014300    포정동
# 44  2711014400  서문로1가
# 45  2711014500    서내동
# 46  2711014600  북성로2가
# 47  2711014700    대안동
# 48  2711014800  동성로1가
# 49  2711014900  태평로2가
# 50  2711015000  북성로1가
# 51  2711015100    화전동
# 52  2711015200    향촌동
# 53  2711015300    북내동
# 54  2711015400    대신동
# 55  2711015500    달성동
# 56  2711015600    남산동
# 57  2711015700    대봉동

# %%
dong_n_code = dong_code_df.values
# make dictionary
dong_n_code = dict(dong_n_code)

# switch key-value {dongName: dongCode}
dong_n_code = {y:x for x,y in dong_n_code.items()}

# %%
dong_n_code
# Out:
# {'계산동1가': 2711013800,
#  '계산동2가': 2711013900,
#  '공평동': 2711012200,
#  '교동': 2711012500,
#  '남산동': 2711015600,
#  '남성로': 2711013700,
#  '남일동': 2711011700,
#  '달성동': 2711015500,
#  '대봉동': 2711015700,
#  '대신동': 2711015400,
#  '대안동': 2711014700,
#  '덕산동': 2711011200,
#  '도원동': 2711012900,
#  '동문동': 2711012000,
#  '동산동': 2711014000,
#  '동성로1가': 2711014800,
#  '동성로2가': 2711012300,
#  '동성로3가': 2711011900,
#  '동인동1가': 2711010100,
#  '동인동2가': 2711010200,
#  '동인동3가': 2711010300,
#  '동인동4가': 2711010400,
#  '동일동': 2711011600,
#  '문화동': 2711012100,
#  '봉산동': 2711010800,
#  '북내동': 2711015300,
#  '북성로1가': 2711015000,
#  '북성로2가': 2711014600,
#  '사일동': 2711011500,
#  '삼덕동1가': 2711010500,
#  '삼덕동2가': 2711010600,
#  '삼덕동3가': 2711010700,
#  '상덕동': 2711012700,
#  '상서동': 2711011000,
#  '서내동': 2711014500,
#  '서문로1가': 2711014400,
#  '서문로2가': 2711014100,
#  '서성로1가': 2711013400,
#  '서성로2가': 2711014200,
#  '서야동': 2711013300,
#  '수동': 2711011100,
#  '수창동': 2711013000,
#  '시장북로': 2711013500,
#  '완전동': 2711012800,
#  '용덕동': 2711012600,
#  '인교동': 2711013200,
#  '장관동': 2711010900,
#  '전동': 2711011800,
#  '종로1가': 2711011300,
#  '종로2가': 2711011400,
#  '태평로1가': 2711012400,
#  '태평로2가': 2711014900,
#  '태평로3가': 2711013100,
#  '포정동': 2711014300,
#  '하서동': 2711013600,
#  '향촌동': 2711015200,
#  '화전동': 2711015100}

# %%
# 기존 데이터에 우리가 방금 정제한 법정동코드 표를 적용합니다.
# 법정동 이름으로, 법정동: 코드 딕셔너리에서 값 가져와서 새로운 column 생성
df['법정동코드'] = df['법정동'].apply(lambda x: dong_n_code[x])

# %%
df.head()
# Out:
#     거래금액  건축년도     년    법정동     아파트  월      일    전용면적   지번   지역코드   층  \
# 0  14500  2007  2007  동인동1가  삼승슈퍼타워  8   1~10   83.50  362  27110   7
# 1  15300  2007  2007  동인동1가  삼승슈퍼타워  8  21~31   83.50  362  27110  14
# 2  16920  2007  2007  동인동1가  삼승슈퍼타워  8  21~31   83.50  362  27110  11
# 3  16000  2006  2007    봉산동   봉산뜨란채  8   1~10   75.95  110  27110   3
# 4   9200  1975  2007     수동    희도맨션  8   1~10  101.26  101  27110   8
#
#         법정동코드
# 0  2711010100
# 1  2711010100
# 2  2711010100
# 3  2711010800
# 4  2711011100

# %% [markdown]
# # 추가 데이터 ( 아파트 세부데이터) 얻기

# %% [markdown]
# ## api를 이용해 아파트 세부 데이터를 얻으려면 아파트 코드가 필요합니다.

# %%
# 법정동 코드의 set값 얻기
loadCode = set(df['법정동코드'])
# 셋에서 리스트로 
loadCode = list(loadCode)

# %%
apt_code_dic = {}
for code in loadCode:
    # 법정동번호로 api 호출해서 법정동에 포함된 모든 아파트 목록 및 아파트 코드 받아오기
    key = '&ServiceKey=이것도 아까처럼 자신의 키를 받아서 복사붙여넣기하시면 됩니다'
    URL = 'http://apis.data.go.kr/1611000/AptListService/getLegaldongAptList?loadCode=' + str(code) + key
    res = urllib.request.urlopen(URL)
    # xml로 파싱
    soup = BeautifulSoup(res, "xml")
    # 모든 아이템 찾기
    items = soup.find_all("item")
    
    for item in items:
        apt_code_dic.update({item.find("kaptName").text: item.find("kaptCode").text})

# 혹시 몰라서 받은 파일을 텍스트 파일로 저장합니다.
with open('apt_code_dic.txt', 'wt') as file:
     json.dump(apt_code_dic, file)

# %%
# 파일읽기
with open('apt_code_dic.txt', 'r') as file:
    apt_code_dic = json.load(file)
    
    
apt_code_dic
# Out:
# {'극동스타클래스남산': 'A70044005',
#  '까치아파트': 'A70075301',
#  '남산그린타운': 'A70044004',
#  '남산휴먼시아1단지': 'A70044002',
#  '남산휴먼시아2단지': 'A70044003',
#  '노마즈하우스': 'A70080001',
#  '대봉청구타운': 'A70081001',
#  '대봉태왕아너스아파트': 'A10027678',
#  '대봉화성파크드림': 'A70081201',
#  '대신센트럴자이': 'A10028088',
#  '동산맨션': 'A70082101',
#  '동인동삼정그린코아': 'A70042401',
#  '동인시티타운': 'A70042101',
#  '라이프아파트': 'A70011101',
#  '반월당삼정그린코아(아파트)': 'A70044202',
#  '보성송림맨션': 'A70072601',
#  '보성황실타운': 'A70075102',
#  '봉산뜨란채': 'A70082301',
#  '삼덕청아람리슈빌': 'A70041301',
#  '센트로팰리스': 'A70081003',
#  '신성미소시티': 'A70071501',
#  '인터불고코아시스': 'A70072401',
#  '청운맨션': 'A70076102',
#  '태왕아너스스카이': 'A70032001',
#  '효성해링턴플레이스': 'A70080201'}

# %%
# 방금 읽어들인 딕셔너리를 이용해서
# 기존 데이터에 아파트코드 열을 새로 만들어 넣습니다.
df['아파트코드'] = df['아파트'].apply(lambda x: apt_code_dic[x] if x in apt_code_dic else None)

# %%
df
# Out:
#        거래금액  건축년도     년    법정동        아파트  월      일    전용면적      지번   지역코드  \
# 0     14500  2007  2007  동인동1가     삼승슈퍼타워  8   1~10   83.50     362  27110
# 1     15300  2007  2007  동인동1가     삼승슈퍼타워  8  21~31   83.50     362  27110
# 2     16920  2007  2007  동인동1가     삼승슈퍼타워  8  21~31   83.50     362  27110
# 3     16000  2006  2007    봉산동      봉산뜨란채  8   1~10   75.95     110  27110
# 4      9200  1975  2007     수동       희도맨션  8   1~10  101.26     101  27110
# 5      5800  1985  2007  태평로1가      태평라이프  8   1~10   54.60   1-187  27110
# 6912   2  2711015700       None
# 6913  16  2711015700  A70081003
# 6914   8  2711015700  A70076102
# 6915   1  2711015700  A70076102
# 6916  20  2711015700  A70081003
# 6917  24  2711015700  A70081003
# 6918   8  2711015700  A70081201
# 6919  22  2711015700       None
# 6920   4  2711015700  A70081003
# 6921  19  2711015700  A70081003
# 6922  13  2711015700  A70081201
# 6923  20  2711015700  A70081003
# 6924   1  2711015700       None
# 6925  13  2711015700  A70081003
#
# [6926 rows x 13 columns]

# %% [markdown]
# 몇몇 아파트는 아파트코드가 없습니다.

# %% [markdown]
# ### 문제가 있네요. 거래내역 데이터 (아파트)와  법정동 아파트목록 데이터 (아파트) 가 매칭이 되지 않습니다.
#  수작업으로 매칭시킴
#  None 값을 가진 13 개의 아파트를 수작업으로 매칭

# %%
missMatch = set(df['아파트'].loc[df['아파트코드'].isnull()])
missMatch
# Out:
# {'건영맨션',
#  '경진테크빌(101동)',
#  '경진테크빌(102동)',
#  '광명',
#  '극동(고려)',
#  '금오맨션',
#  '까치',
#  '나누리',
#  '남문시장2지구',
#  '남산모던',
#  '대봉 태왕아너스',
#  '대봉맨션',
#  '대봉화성그린빌',
#  '대신',
#  '대신 센트럴자이',
#  '대흥아트',
#  '도원',
#  '동남',
#  '동삼(88-0)',
#  '동서',
#  '동인(279-1)',
#  '동인(341-2)',
#  '동인태평78',
#  '미소시티',
#  '반월당삼정그린코아',
#  '반월당효성해링턴플레이스',
#  '부림베스트빌',
#  '삼덕드림타운',
#  '삼덕아이파크',
#  '삼덕인베스트',
#  '삼덕청아람',
#  '삼성솔라',
#  '삼승슈퍼타워',
#  '삼익맨션',
#  '서성로훼밀리타운',
#  '석우리치타운',
#  '센텀리움',
#  '송림맨션',
#  '시티타운',
#  '심미한마음',
#  '아진맨션',
#  '아트빌',
#  '지성하이츠',
#  '청구맨션',
#  '태평',
#  '태평라이프',
#  '한양가든테라스',
#  '허브스카이',
#  '현서그린',
#  '홍길',
#  '황궁',
#  '희도맨션'}

# %% [markdown]
# 잘못된 아파트이름 다 변경

# %%
# 아파트값 변경을위해 딕셔너리 생성 {old_apt_name: new_apt_name}
old_new = {'극동(고려)': '극동스타클래스남산', '까치': '까치아파트', '대봉 태왕아너스': '대봉태왕아너스아파트', '대신 센트럴자이': '대신센트럴자이',
          '미소시티': '신성미소시티', '반월당삼정그린코아': '반월당삼정그린코아(아파트)', '반월당효성해링턴플레이스': '효성해링턴플레이스',
           '삼덕청아람': '삼덕청아람리슈빌', '송림맨션': '보성송림맨션', '시티타운': '동인시티타운', '청구맨션': '대봉청구타운', '태평라이프': '라이프아파트'}
old_new
# Out:
# {'극동(고려)': '극동스타클래스남산',
#  '까치': '까치아파트',
#  '대봉 태왕아너스': '대봉태왕아너스아파트',
#  '대신 센트럴자이': '대신센트럴자이',
#  '미소시티': '신성미소시티',
#  '반월당삼정그린코아': '반월당삼정그린코아(아파트)',
#  '반월당효성해링턴플레이스': '효성해링턴플레이스',
#  '삼덕청아람': '삼덕청아람리슈빌',
#  '송림맨션': '보성송림맨션',
#  '시티타운': '동인시티타운',
#  '청구맨션': '대봉청구타운',
#  '태평라이프': '라이프아파트'}

# %% [markdown]
# ### groupby: 나누고 -> 적용하고 -> 합치기

# %% [markdown]
# - groupby로 데이터프레임의 아파트 칼럼에서 까치인 sub데이터프레임으로 나누고, 까치를 까치아파트로 다 바꾸고 다시 원래 데이터프레임에 합친다.
# - group = df.groupby(df['아파트']=='까치').apply(lambda x: x.replace('까치', '까치아파트'))
# - df[df['아파트']=='까치'] = group

# %%
# 안맞는 아파트 이름을 다 변경합니다.
for old, new in old_new.items():
    group = df.groupby(df['아파트']==old).apply(lambda x: x.replace(old, new))
    df[df['아파트']==old] = group

# %%
# 그리고 아파트 코드를 할당해줍니다.
df['아파트코드'] = df['아파트'].apply(lambda x: apt_code_dic[x] if x in apt_code_dic else None)

# %%
df
# Out:
#        거래금액  건축년도     년    법정동         아파트  월      일    전용면적      지번   지역코드  \
# 0     14500  2007  2007  동인동1가      삼승슈퍼타워  8   1~10   83.50     362  27110
# 1     15300  2007  2007  동인동1가      삼승슈퍼타워  8  21~31   83.50     362  27110
# 2     16920  2007  2007  동인동1가      삼승슈퍼타워  8  21~31   83.50     362  27110
# 3     16000  2006  2007    봉산동       봉산뜨란채  8   1~10   75.95     110  27110
# 4      9200  1975  2007     수동        희도맨션  8   1~10  101.26     101  27110
# 5      5800  1985  2007  태평로1가      라이프아파트  8   1~10   54.60   1-187  27110
# 6      5500  1985  2007  태평로1가      라이프아파트  8   1~10   54.60   1-187  27110
# 7      5100  1976  2007    도원동          도원  8   1~10   38.91     3-5  27110
# 8     12500  2007  2007    동산동      석우리치타운  8   1~10   81.90     5-2  27110
# 9     12500  2007  2007    동산동      석우리치타운  8  11~20   81.90     5-2  27110
# 10    43000  2006  2007    대신동    태왕아너스스카이  8  21~31  191.39   305-1  27110
# 11     9500  1985  2007    대신동          동서  8  21~31   65.06    1450  27110
# 12     7700  1984  2007    달성동        금오맨션  8  21~31   78.00   118-3  27110
# 13    25000  1993  2007    남산동      보성황실타운  8   1~10  163.72  2466-1  27110
# 14     4050  1992  2007    남산동       까치아파트  8   1~10   33.06  2482-1  27110
# 15     8850  1992  2007    남산동      보성송림맨션  8  11~20   59.99    2434  27110
# 16     7000  1993  2007    남산동      보성황실타운  8  11~20   59.96  2466-1  27110
# 17     9500  1993  2007    남산동      보성황실타운  8  11~20   59.96  2466-1  27110
# 18     9400  1992  2007    남산동      보성송림맨션  8  21~31   59.99    2434  27110
# 19    31668  2006  2007    남산동       허브스카이  8  21~31   99.92   654-1  27110
# 20    22936  2006  2007    남산동       허브스카이  8  21~31   84.88   654-1  27110
# 21    10450  2000  2007    대봉동         아트빌  8   1~10   78.58   44-13  27110
# 22    19000  1986  2007    대봉동        청운맨션  8  11~20  128.07   44-10  27110
# 23    17400  1986  2007    대봉동        청운맨션  8  21~31   84.93   44-10  27110
# 24    22700  2007  2007    대봉동      센트로팰리스  8  21~31   80.71   60-10  27110
# 6925  44500  2007  2017    대봉동      센트로팰리스  8  21~31   80.74   60-10  27110
#
#        층       법정동코드      아파트코드
# 0      7  2711010100       None
# 1     14  2711010100       None
# 2     11  2711010100       None
# 3      3  2711010800  A70082301
# 4      8  2711011100       None
# 5      8  2711012400  A70011101
# 6      6  2711012400  A70011101
# 7      2  2711012900       None
# 8      4  2711014000       None
# 9      3  2711014000       None
# 10     8  2711015400  A70032001
# 11     4  2711015400       None
# 12     4  2711015500       None
# 13     3  2711015600  A70075102
# 14     5  2711015600  A70075301
# 15     2  2711015600  A70072601
# 16    10  2711015600  A70075102
# 17     3  2711015600  A70075102
# 18    13  2711015600  A70072601
# 19    17  2711015600       None
# 20     6  2711015600       None
# 21     4  2711015700       None
# 22     4  2711015700  A70076102
# 23    11  2711015700  A70076102
# 24    18  2711015700  A70081003
# 25     9  2711010100       None
# 26    10  2711010100       None
# 27    10  2711010100       None
# 28     7  2711012400  A70011101
# 29     7  2711014000  A70082101
# ...   ..         ...        ...
# 6896  12  2711015600  A70075102
# 6897  16  2711015600  A70075102
# 6898  20  2711015600  A70044004
# 6899  15  2711015600  A70044004
# 6900   6  2711015600  A70075301
# 6901  15  2711015600  A70072401
# 6902  22  2711015600  A70044005
# 6903  16  2711015600  A70044003
# 6904   7  2711015600  A70075102
# 6905  16  2711015600  A70075102
# 6906   1  2711015700  A70081001
# 6907  27  2711015700  A70081003
# 6908   1  2711015700  A70081001
# 6909  18  2711015700  A10027678
# 6910   1  2711015700  A70081201
# 6911  21  2711015700  A70081003
# 6912   2  2711015700  A10027678
# 6913  16  2711015700  A70081003
# 6914   8  2711015700  A70076102
# 6915   1  2711015700  A70076102
# 6916  20  2711015700  A70081003
# 6917  24  2711015700  A70081003
# 6918   8  2711015700  A70081201
# 6919  22  2711015700  A10027678
# 6920   4  2711015700  A70081003
# 6921  19  2711015700  A70081003
# 6922  13  2711015700  A70081201
# 6923  20  2711015700  A70081003
# 6924   1  2711015700  A70081001
# 6925  13  2711015700  A70081003
#
# [6926 rows x 13 columns]

# %%
# 아파트코드가 있는지 없는지 확인
set(df['아파트'].loc[df['아파트코드'].isnull()])
# Out:
# {'건영맨션',
#  '경진테크빌(101동)',
#  '경진테크빌(102동)',
#  '광명',
#  '금오맨션',
#  '나누리',
#  '남문시장2지구',
#  '남산모던',
#  '대봉맨션',
#  '대봉화성그린빌',
#  '대신',
#  '대흥아트',
#  '도원',
#  '동남',
#  '동삼(88-0)',
#  '동서',
#  '동인(279-1)',
#  '동인(341-2)',
#  '동인태평78',
#  '부림베스트빌',
#  '삼덕드림타운',
#  '삼덕아이파크',
#  '삼덕인베스트',
#  '삼성솔라',
#  '삼승슈퍼타워',
#  '삼익맨션',
#  '서성로훼밀리타운',
#  '석우리치타운',
#  '센텀리움',
#  '심미한마음',
#  '아진맨션',
#  '아트빌',
#  '지성하이츠',
#  '태평',
#  '한양가든테라스',
#  '허브스카이',
#  '현서그린',
#  '홍길',
#  '황궁',
#  '희도맨션'}

# %% [markdown]
# 40개의 아파트가 아파트코드가 없습니다.

# %% [markdown]
# # Get Extra Data

# %% [markdown]
# K-APT api사용
# 1. 아파트 코드 사용해서
# 2. 아파트 단지정보 받아오기

# %%
# 아파트 디테일 정보 가져오기

# 필요한 데이터 키값
list_of_data = ['CODE_HALL', 'CODE_HEAT', 'CODE_SEC', 'CODE_STR', 'CONVENIENT_FACILITY', 'EDUCATION_FACILITY',
                'KAPTD_PCNT','KAPTD_PCNTU', 'KAPTD_WTIMEBUS', 'KAPTD_WTIMESUB', 'KAPT_DONG_CNT', 'KAPT_MGR_CNT',
                'KAPTD_ECNTP', 'KAPT_USEDATE', 'SUBWAY_LINE', 'SUBWAY_STATION', 'WELFARE_FACILITY']

# 필요한 모든 아파트 세부정보
details_data = {}

for v in apt_code_dic.values():
    response = urllib.request.urlopen("http://www.k-apt.go.kr/kaptinfo/getKaptInfo_detail.do?kapt_code=" + str(v))
    data = json.loads(response.read().decode('utf-8'))
    apt_data = {}
    for tem in list_of_data:
        apt_data.update({tem: data['resultMap_kapt'][tem]})
    details_data.update({v: apt_data})

# %%
'''
아파트 세부정보 데이터의 구조
{
    {아파트코드1: {  데이터1: 값1, 
                        데이터2: 값2,
                        데이터3: 값3,
                        ...  : ...
                      }
    },
    {아파트코드2: {  데이터1: 값1, 
                        데이터2: 값2,
                        데이터3: 값3,
                        ...  : ...
                      }
    },
}
'''

details_data
# Out:
# {'A10027678': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '-',
#   'EDUCATION_FACILITY': '-',
#   'KAPTD_ECNTP': 10,
#   'KAPTD_PCNT': '102',
#   'KAPTD_PCNTU': '400',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '6',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '2015-11-25',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '대구2호선',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A10028088': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구중부소방서) 병원(계명대학교 동산병원) 백화점(현대백화점,동아백화점) 대형상가(서문시장) 공원(달성공원) 기타()',
#   'EDUCATION_FACILITY': '초등학교(계성초교,대구남산초교) 중학교(계성중교) 고등학교(계성고교) 대학교(대구카톨릭대학교)',
#   'KAPTD_ECNTP': 24,
#   'KAPTD_PCNT': '175',
#   'KAPTD_PCNTU': '1321',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '13',
#   'KAPT_MGR_CNT': '8',
#   'KAPT_USEDATE': '2015-04-15',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '-',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤니티공간, 자전거보관소, 기타'},
#  'A70011101': {'CODE_HALL': '복도식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '자치관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구광역시청,대구세무서,중부경찰서,대구우체국,대구지방병무청) 병원(곽병원) 백화점(롯데백화점,동아백화점) 대형상가(칠성시장) 공원(국채보상기념공원) 기타(아미고호텔,대구역)',
#   'EDUCATION_FACILITY': '초등학교(옥산초,종로초) 중학교(경명여중) 고등학교(경명여고)',
#   'KAPTD_ECNTP': 2,
#   'KAPTD_PCNT': '80',
#   'KAPTD_PCNTU': '76',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '1',
#   'KAPT_MGR_CNT': '2',
#   'KAPT_USEDATE': '1985-07-15',
#   'SUBWAY_LINE': '1호선',
#   'SUBWAY_STATION': '대구',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 자전거보관소'},
#  'A70032001': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대신동사무소) 병원(동산의료원) 대형상가(서문시장지구)',
#   'EDUCATION_FACILITY': '초등학교(계성초,남산초) 중학교(계성중,성명여중) 고등학교(신명고) 대학교(계명대의과대학,동산간호전문대)',
#   'KAPTD_ECNTP': 11,
#   'KAPTD_PCNT': '249',
#   'KAPTD_PCNTU': '536',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '6',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '2006-10-25',
#   'SUBWAY_LINE': '2호선, 3호선',
#   'SUBWAY_STATION': '신남',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A70041301': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(중구청,동인동사무소,삼덕동우체국,동인3가파출소,국민연금관리공단남대구지사) 병원(경북의대부속병원) 백화점(대백프라자) 대형상가(동부시장) 공원(국채보상기념공원)',
#   'EDUCATION_FACILITY': '초등학교(사대부초,동덕초,동인초,삼덕초) 중학교(대구중앙중,신명여중) 고등학교(남산고,중앙경영정보고) 대학교(경대의대,경대의대보건대학원,경대치대)',
#   'KAPTD_ECNTP': 14,
#   'KAPTD_PCNT': '8',
#   'KAPTD_PCNTU': '930',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '7',
#   'KAPT_MGR_CNT': '6',
#   'KAPT_USEDATE': '2013-04-03',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '경대병원',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A70042101': {'CODE_HALL': '혼합식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구광역시청,한국전력공사,동인변전소,대구우체국,대구지방병무청,중부경찰서,대구시중구청) 병원(경북의대부속병원) 백화점(롯데백화점,동아백화점) 대형상가(칠성시장) 공원(국채보상기념공원) 기타(대구역)',
#   'EDUCATION_FACILITY': '초등학교(동인초,동덕초,대구초,경북대사범부속초) 대학교(경대의과대,경대의과대보건대학원,경대치대)',
#   'KAPTD_ECNTP': 4,
#   'KAPTD_PCNT': '82',
#   'KAPTD_PCNTU': '56',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '15~20분이내',
#   'KAPT_DONG_CNT': '1',
#   'KAPT_MGR_CNT': '2',
#   'KAPT_USEDATE': '1997-07-11',
#   'SUBWAY_LINE': '1호선',
#   'SUBWAY_STATION': '칠성시장',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A70042401': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '-',
#   'CONVENIENT_FACILITY': '관공서(대구시청, 중구청) 병원(경북대병원) 공원(국채보상기념공원) 기타(한국은행,KT)',
#   'EDUCATION_FACILITY': '초등학교(동인초,동덕초) 중학교(대구중앙중) 고등학교(중앙정보고) 대학교(경북대의대)',
#   'KAPTD_ECNTP': 5,
#   'KAPTD_PCNT': '25',
#   'KAPTD_PCNTU': '203',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '-',
#   'KAPT_DONG_CNT': '1',
#   'KAPT_MGR_CNT': '2',
#   'KAPT_USEDATE': '2009-03-05',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '-',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A70044002': {'CODE_HALL': '혼합식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구중부소방서, 동부교육청, 우체국) 병원(동산의료원) 백화점(동아쇼핑센타) 대형상가(서문시장) 공원(달성공원)',
#   'EDUCATION_FACILITY': '초등학교(계성초, 남산초) 중학교(계성중, 성명중, 경구중교) 고등학교(계성고, 신명고교) 대학교(계명대및 대구대 대명동캠퍼스, 카톨릭대남산캠퍼스)',
#   'KAPTD_ECNTP': 10,
#   'KAPTD_PCNT': '97',
#   'KAPTD_PCNTU': '407',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '5',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '2008-10-28',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '신남',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소'},
#  'A70044003': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구중부소방서, 동부교육청, 우체국) 병원(동산의료원) 백화점(동아쇼핑센타) 대형상가(서문시장) 공원(달성공원)',
#   'EDUCATION_FACILITY': '초등학교(계성초, 남산초교) 중학교(계성중, 성명중, 경구중교) 고등학교(계성고, 신명고교) 대학교(계명대및 대구대 대명동캠퍼스, 카톨릭대남산캠퍼스)',
#   'KAPTD_ECNTP': 14,
#   'KAPTD_PCNT': '197',
#   'KAPTD_PCNTU': '475',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '6',
#   'KAPT_MGR_CNT': '6',
#   'KAPT_USEDATE': '2008-10-28',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '신남',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소, 기타'},
#  'A70044004': {'CODE_HALL': '혼합식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구도시가스,동사무소,계명대학우체국,대구도시가스,대구중부소방서) 병원(동산의료원, 한독병원) 대형상가(서문시장) 기타(프린스호텔,대구보명학교,대구영화학교,대구보건학교,영화맹아학교)',
#   'EDUCATION_FACILITY': '초등학교(계성초,남산초,내당초) 중학교(구남중,계성중,경구중,신명여중) 고등학교(구남여자경영정보고,계성고,경북공업고,신명고 동성고) 대학교(계명대,대구대,대구가톨릭대,대구가톨릭대학원)',
#   'KAPTD_ECNTP': 0,
#   'KAPTD_PCNT': '67',
#   'KAPTD_PCNTU': '798',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '8',
#   'KAPT_MGR_CNT': '6',
#   'KAPT_USEDATE': '2005-04-27',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '반고개',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A70044005': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(신남치안센터, 동부교육청,대구도시가스,동사무소,남산동우체국,대구도시가스,대구중부소방서) 병원(동산병원) 대형상가(서문시장) 기타(프린스호텔,대구영화학교,대구보명학교,영화맹아학교,대구보건학교)',
#   'EDUCATION_FACILITY': '초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(구남여자경영정보고,경북여자경영정보고,경북예술고,경북공업고,경북여고) 대학교(계명대,대구대,대구교육대,대구가톨릭대,대구가톨릭대학원)',
#   'KAPTD_ECNTP': 20,
#   'KAPTD_PCNT': '90',
#   'KAPTD_PCNTU': '1174',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '10',
#   'KAPT_MGR_CNT': '7',
#   'KAPT_USEDATE': '2014-04-30',
#   'SUBWAY_LINE': '2호선, 3호선',
#   'SUBWAY_STATION': '명덕,신남',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤니티공간, 자전거보관소'},
#  'A70044202': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(남산2동주민센터, 대구시 동부교육청) 병원(동산병원,경대병원) 백화점(동아쇼핑,대구백화점) 대형상가(서문시장,남문시장) 공원(국채보상기념공원)',
#   'EDUCATION_FACILITY': '초등학교(대구초,계성초) 중학교(제일중,계성중) 고등학교(경북여고,계성고) 대학교(계명대학 의과대학,경북대학 의과대학)',
#   'KAPTD_ECNTP': 10,
#   'KAPTD_PCNT': '554',
#   'KAPTD_PCNTU': '524',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '3',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '2007-07-27',
#   'SUBWAY_LINE': '1호선, 2호선',
#   'SUBWAY_STATION': '반월당',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 어린이놀이터, 자전거보관소'},
#  'A70071501': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철골철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(중앙파출소, 성내2동 주민센터, 대구시 동부 교육청, 남산지구대) 병원(동산병원) 백화점(동아쇼핑, 현대백화점) 대형상가(서문시장) 공원(달성공원)',
#   'EDUCATION_FACILITY': '초등학교(남산초,) 중학교(성명여중) 고등학교(신명고) 대학교(계명대 의과대학)',
#   'KAPTD_ECNTP': 5,
#   'KAPTD_PCNT': '7',
#   'KAPTD_PCNTU': '605',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '2',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '2007-10-09',
#   'SUBWAY_LINE': '1호선, 2호선',
#   'SUBWAY_STATION': '반월당',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소'},
#  'A70072401': {'CODE_HALL': '복도식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대구시 동부교육청, 남산2동주민센터, 남산지구대) 병원(동산의료원) 백화점(현대백화점,동아쇼핑) 대형상가(남문시장) 공원(국채보상기념공원)',
#   'EDUCATION_FACILITY': '초등학교(대구초,남산초) 중학교(성명여중,계성중) 고등학교(신명고,계성고) 대학교(계명대학 의과대학,대구카톨릭대 남산캠퍼스)',
#   'KAPTD_ECNTP': 0,
#   'KAPTD_PCNT': '11',
#   'KAPTD_PCNTU': '108',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '1',
#   'KAPT_MGR_CNT': '3',
#   'KAPT_USEDATE': '2014-02-07',
#   'SUBWAY_LINE': '1호선, 2호선',
#   'SUBWAY_STATION': '반월당',
#   'WELFARE_FACILITY': '관리사무소, 주민공동시설'},
#  'A70072601': {'CODE_HALL': '혼합식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '자치관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(동부교육청,대구도시가스,동사무소,남산동우체국,남구보건소) 병원(대구적십자병원) 백화점(동아쇼핑센터) 대형상가(남문시장) 기타(프린스호텔)',
#   'EDUCATION_FACILITY': '초등학교(남산초,남대구초,명덕초) 중학교(경구중,제일중,경상중) 고등학교(경북공업고,경북여자경영정보고,경북예술고,경북여고) 대학교(대구가톨릭대,대구가톨릭대학원,대구교육대,계명대)',
#   'KAPTD_ECNTP': 8,
#   'KAPTD_PCNT': '142',
#   'KAPTD_PCNTU': '79',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '15~20분이내',
#   'KAPT_DONG_CNT': '3',
#   'KAPT_MGR_CNT': '4',
#   'KAPT_USEDATE': '1992-12-17',
#   'SUBWAY_LINE': '1호선, 2호선, 3호선',
#   'SUBWAY_STATION': '명덕,신남',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 어린이놀이터'},
#  'A70075102': {'CODE_HALL': '혼합식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(동부교육청,대구도시가스,동사무소,남산동우체국,대구도시가스,대구중부소방서) 병원(한독병원,남산병원) 대형상가(남문시장) 기타(프린스호텔,대구보명학교,대구영화학교,영화맹화학교,대구보건학교)',
#   'EDUCATION_FACILITY': '초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(경북여고,경북공업고,경북여자경영정보고,경북예술고,구남여자경영정보고) 대학교(대구가톨릭대,대구가톨릭대학원,대구교육대,계명대,대구대)',
#   'KAPTD_ECNTP': 20,
#   'KAPTD_PCNT': '523',
#   'KAPTD_PCNTU': '536',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '15~20분이내',
#   'KAPT_DONG_CNT': '8',
#   'KAPT_MGR_CNT': '8',
#   'KAPT_USEDATE': '1993-03-29',
#   'SUBWAY_LINE': '1호선, 3호선',
#   'SUBWAY_STATION': '명덕',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 주민공동시설, 어린이놀이터'},
#  'A70075301': {'CODE_HALL': '복도식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(신남치안센터, 동부교육청,대구도시가스,동사무소,남산동우체국,대구도시가스,대구중부소방서) 병원(한독병원) 백화점(현대백화점) 대형상가(남문시장) 공원(달성공원) 기타(프린스호텔,대구영화학교,대구보명학교,영화맹아학교,대구보건학교)',
#   'EDUCATION_FACILITY': '초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(구남여자경영정보고,경북여자경영정보고,경북예술고,경북공업고,경북여고) 대학교(계명대,대구대,대구교육대,대구가톨릭대,대구가톨릭대학원)',
#   'KAPTD_ECNTP': 10,
#   'KAPTD_PCNT': '200',
#   'KAPTD_PCNTU': '0',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '10~15분이내',
#   'KAPT_DONG_CNT': '3',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '1992-06-30',
#   'SUBWAY_LINE': '2호선, 3호선',
#   'SUBWAY_STATION': '명덕',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 어린이놀이터'},
#  'A70076102': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '중앙난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(국민연금관리공단남대구지사,대구광역시교육위원회,대봉동사무소,대봉우체국,대봉치안센터) 병원(인제병원) 백화점(대백프라자) 공원(유원지질) 기타(대봉도서관)',
#   'EDUCATION_FACILITY': '초등학교(동덕초,삼덕초,대봉초) 중학교(신명여중) 고등학교(남산고) 대학교(경대치대)',
#   'KAPTD_ECNTP': 27,
#   'KAPTD_PCNT': '713',
#   'KAPTD_PCNTU': '0',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '10~15분이내',
#   'KAPT_DONG_CNT': '7',
#   'KAPT_MGR_CNT': '8',
#   'KAPT_USEDATE': '1986-12-05',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '경대병원',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 어린이놀이터, 자전거보관소'},
#  'A70080001': {'CODE_HALL': '복도식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '자치관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(교동119안전센터,대구역전우체국, 대구시청,중구청) 병원(경북대학교 병원) 기타(번개시장)',
#   'EDUCATION_FACILITY': '대학교(경북대학교 의대)',
#   'KAPTD_ECNTP': 0,
#   'KAPTD_PCNT': '0',
#   'KAPTD_PCNTU': '218',
#   'KAPTD_WTIMEBUS': '10~15분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '1',
#   'KAPT_MGR_CNT': '4',
#   'KAPT_USEDATE': '2014-01-21',
#   'SUBWAY_LINE': '1호선',
#   'SUBWAY_STATION': '-',
#   'WELFARE_FACILITY': '관리사무소'},
#  'A70080201': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '병원() 백화점() 대형상가()',
#   'EDUCATION_FACILITY': '초등학교() 중학교() 고등학교()',
#   'KAPTD_ECNTP': 12,
#   'KAPTD_PCNT': '467',
#   'KAPTD_PCNTU': '203',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '5',
#   'KAPT_MGR_CNT': '5',
#   'KAPT_USEDATE': '2014-07-31',
#   'SUBWAY_LINE': '1호선',
#   'SUBWAY_STATION': '반월당역',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤니티공간, 자전거보관소, 기타'},
#  'A70081001': {'CODE_HALL': '복도식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '자치관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대봉동사무소,대봉우체국,대봉치안센터) 병원(인제병원,경대치과병원) 백화점(대백프라자) 대형상가(남문시장)',
#   'EDUCATION_FACILITY': '초등학교(영선초,삼덕초,동인초) 중학교(경북대사범부속중,신명여중,제일중) 고등학교(경북여고,남산고,경북대사범부속고) 대학교(경대의과대학,경대의과대학보건대학원)',
#   'KAPTD_ECNTP': 4,
#   'KAPTD_PCNT': '87',
#   'KAPTD_PCNTU': '0',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '2',
#   'KAPT_MGR_CNT': '1',
#   'KAPT_USEDATE': '1978-11-18',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '경대병원',
#   'WELFARE_FACILITY': '관리사무소, 어린이놀이터, 자전거보관소'},
#  'A70081003': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대봉도서관,대구동부교육청,시립중앙도서관) 병원(경대치과병원) 백화점(대구백화점,동아쇼핑) 대형상가(갤러리존) 공원(국채보상공원,대구향교)',
#   'EDUCATION_FACILITY': '초등학교(대구초,경대사대부속초,삼덕초) 중학교(경대사대부속중,제일여중,신명여중) 고등학교(경대사대부속고,남산고) 대학교(경북대치대,경북대의대)',
#   'KAPTD_ECNTP': 16,
#   'KAPTD_PCNT': '0',
#   'KAPTD_PCNTU': '1270',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '7',
#   'KAPT_MGR_CNT': '14',
#   'KAPT_USEDATE': '2007-03-23',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '경대병원역',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤니티공간, 자전거보관소, 기타'},
#  'A70081201': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(대봉동사무소,대봉우체국,대봉치안센터) 병원(남부보건소) 백화점(대백프라자) 대형상가(남문시장) 기타(대구외국인학교,건들바위)',
#   'EDUCATION_FACILITY': '초등학교(대구초,경북대사범부속초,명덕초,영선초) 중학교(신명여중,제일중,경북대사범부속중) 고등학교(경북대사범부속고,남산고,경북여고) 대학교(경대치대)',
#   'KAPTD_ECNTP': 11,
#   'KAPTD_PCNT': '123',
#   'KAPTD_PCNTU': '181',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '5분이내',
#   'KAPT_DONG_CNT': '3',
#   'KAPT_MGR_CNT': '3',
#   'KAPT_USEDATE': '2006-05-22',
#   'SUBWAY_LINE': '3호선',
#   'SUBWAY_STATION': '명덕',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 어린이놀이터, 자전거보관소'},
#  'A70082101': {'CODE_HALL': '복도식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(중부경찰서,대구우체국,대구지방병무청,동부교육청,동사무소) 병원(곽병원) 백화점(동아쇼핑,대구백화점) 대형상가(서문시장) 공원(달성공원) 기타(아미고호텔)',
#   'EDUCATION_FACILITY': '초등학교(종로초,수창초,계성초,대성초,남산초,대구초) 중학교(계성중,성명여중) 고등학교(계성고,신명고,경신정보과학고) 대학교(계명대의과대학,동산간호전문대)',
#   'KAPTD_ECNTP': 2,
#   'KAPTD_PCNT': '100',
#   'KAPTD_PCNTU': '18',
#   'KAPTD_WTIMEBUS': '5분이내',
#   'KAPTD_WTIMESUB': '5~10분이내',
#   'KAPT_DONG_CNT': '1',
#   'KAPT_MGR_CNT': '1',
#   'KAPT_USEDATE': '1986-12-10',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '신남역',
#   'WELFARE_FACILITY': '관리사무소, 어린이놀이터, 자전거보관소'},
#  'A70082301': {'CODE_HALL': '계단식',
#   'CODE_HEAT': '개별난방',
#   'CODE_SEC': '위탁관리',
#   'CODE_STR': '철근콘크리트구조',
#   'CONVENIENT_FACILITY': '관공서(동부교육청,주민센터) 병원(경북대의대) 백화점(동아쇼핑센터) 대형상가(삼성금융프라자) 기타(남문시장)',
#   'EDUCATION_FACILITY': '초등학교(경북대사범부속초,명덕초,영선초) 중학교(제일중,경북대사범부속중) 고등학교(경북여고,경북대사범부속고) 대학교(대구가톨릭대,대구가톨릭대학원)',
#   'KAPTD_ECNTP': 0,
#   'KAPTD_PCNT': '111',
#   'KAPTD_PCNTU': '184',
#   'KAPTD_WTIMEBUS': '5~10분이내',
#   'KAPTD_WTIMESUB': '10~15분이내',
#   'KAPT_DONG_CNT': '3',
#   'KAPT_MGR_CNT': '3',
#   'KAPT_USEDATE': '2006-08-18',
#   'SUBWAY_LINE': '2호선',
#   'SUBWAY_STATION': '경대병원',
#   'WELFARE_FACILITY': '관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소'}}

# %% [markdown]
# 받은 데이터를 csv로 저장합니다. 혹시모르니까요 ^~^

# %%
# 딕셔너리를 csv파일로 저장합니다.
with open('apt_details.csv', "w", newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    # 헤더를 쓰고
    writer.writerow(list_of_data)
    
    # 모든키를 순회
    for k, v in details_data.items():
        # 리스트 생성
        contents = []
        # 키를 먼저 넣고
        contents.append(k)  # key
        
        # 모든값을 순회
        for i in range(len(list_of_data)):
            contents.append(details_data[k][list_of_data[i]])  # 값들
        writer.writerow(contents)

# %%
# 저장된 csv파일을 다시 result로 불러들입니다.
result = pd.read_csv('apt_details.csv')
result
# Out:
#           CODE_HALL CODE_HEAT CODE_SEC    CODE_STR  \
# A70071501       계단식      개별난방     위탁관리  철골철근콘크리트구조
# A70041301       계단식      개별난방     위탁관리    철근콘크리트구조
# A70076102       계단식      중앙난방     위탁관리    철근콘크리트구조
# A70081003       계단식      개별난방     위탁관리    철근콘크리트구조
# A10027678       계단식      개별난방     위탁관리    철근콘크리트구조
# A70081001       복도식      개별난방     자치관리    철근콘크리트구조
# A70081201       계단식      개별난방     위탁관리    철근콘크리트구조
# A70080001       복도식      개별난방     자치관리    철근콘크리트구조
# A70011101       복도식      개별난방     자치관리    철근콘크리트구조
# A70044004       혼합식      개별난방     위탁관리    철근콘크리트구조
# A70072401       복도식      개별난방     위탁관리    철근콘크리트구조
# A70075301       복도식      개별난방     위탁관리    철근콘크리트구조
# A10028088  관공서(대구중부소방서) 병원(계명대학교 동산병원) 백화점(현대백화점,동아백화점) 대...
# A70032001                 관공서(대신동사무소) 병원(동산의료원) 대형상가(서문시장지구)
# A70082301  관공서(동부교육청,주민센터) 병원(경북대의대) 백화점(동아쇼핑센터) 대형상가(삼성금...
# A70082101  관공서(중부경찰서,대구우체국,대구지방병무청,동부교육청,동사무소) 병원(곽병원) 백화...
#
#                                           EDUCATION_FACILITY  KAPTD_PCNT  \
# A70071501       초등학교(남산초,) 중학교(성명여중) 고등학교(신명고) 대학교(계명대 의과대학)           7
# A70041301  초등학교(사대부초,동덕초,동인초,삼덕초) 중학교(대구중앙중,신명여중) 고등학교(남산...           8
# A70076102    초등학교(동덕초,삼덕초,대봉초) 중학교(신명여중) 고등학교(남산고) 대학교(경대치대)         713
# A70081003  초등학교(대구초,경대사대부속초,삼덕초) 중학교(경대사대부속중,제일여중,신명여중) 고...           0
# A10027678                                                  -         102
# A70081001  초등학교(영선초,삼덕초,동인초) 중학교(경북대사범부속중,신명여중,제일중) 고등학교(...          87
# A70081201  초등학교(대구초,경북대사범부속초,명덕초,영선초) 중학교(신명여중,제일중,경북대사범부...         123
# A70080001                                      대학교(경북대학교 의대)           0
# A70011101                 초등학교(옥산초,종로초) 중학교(경명여중) 고등학교(경명여고)          80
# A70044004  초등학교(계성초,남산초,내당초) 중학교(구남중,계성중,경구중,신명여중) 고등학교(구...          67
# A70072401  초등학교(대구초,남산초) 중학교(성명여중,계성중) 고등학교(신명고,계성고) 대학교(...          11
# A70075301  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(구...         200
# A70044003  초등학교(계성초, 남산초교) 중학교(계성중, 성명중, 경구중교) 고등학교(계성고, ...         197
# A70044002  초등학교(계성초, 남산초) 중학교(계성중, 성명중, 경구중교) 고등학교(계성고, 신...          97
# A70044005  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(구...          90
# A70072601  초등학교(남산초,남대구초,명덕초) 중학교(경구중,제일중,경상중) 고등학교(경북공업고...         142
# A70080201                                초등학교() 중학교() 고등학교()         467
# A70044202  초등학교(대구초,계성초) 중학교(제일중,계성중) 고등학교(경북여고,계성고) 대학교(...         554
# A70075102  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(경...         523
# A70042101  초등학교(동인초,동덕초,대구초,경북대사범부속초) 대학교(경대의과대,경대의과대보건대학...          82
# A70042401    초등학교(동인초,동덕초) 중학교(대구중앙중) 고등학교(중앙정보고) 대학교(경북대의대)          25
# A10028088  초등학교(계성초교,대구남산초교) 중학교(계성중교) 고등학교(계성고교) 대학교(대구카...         175
# A70032001  초등학교(계성초,남산초) 중학교(계성중,성명여중) 고등학교(신명고) 대학교(계명대의...         249
# A70082301  초등학교(경북대사범부속초,명덕초,영선초) 중학교(제일중,경북대사범부속중) 고등학교(...         111
# A70082101  초등학교(종로초,수창초,계성초,대성초,남산초,대구초) 중학교(계성중,성명여중) 고등...         100
# 8                  초등학교(옥산초,종로초) 중학교(경명여중) 고등학교(경명여고)          80
# 9   초등학교(계성초,남산초,내당초) 중학교(구남중,계성중,경구중,신명여중) 고등학교(구...          67
# 10  초등학교(대구초,남산초) 중학교(성명여중,계성중) 고등학교(신명고,계성고) 대학교(...          11
# 11  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(구...         200
# 12  초등학교(계성초, 남산초교) 중학교(계성중, 성명중, 경구중교) 고등학교(계성고, ...         197
# 13  초등학교(계성초, 남산초) 중학교(계성중, 성명중, 경구중교) 고등학교(계성고, 신...          97
# 14  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(구...          90
# 15  초등학교(남산초,남대구초,명덕초) 중학교(경구중,제일중,경상중) 고등학교(경북공업고...         142
# 16                                초등학교() 중학교() 고등학교()         467
# 17  초등학교(대구초,계성초) 중학교(제일중,계성중) 고등학교(경북여고,계성고) 대학교(...         554
# 18  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(경...         523
# 19  초등학교(동인초,동덕초,대구초,경북대사범부속초) 대학교(경대의과대,경대의과대보건대학...          82
# 20    초등학교(동인초,동덕초) 중학교(대구중앙중) 고등학교(중앙정보고) 대학교(경북대의대)          25
# 21  초등학교(계성초교,대구남산초교) 중학교(계성중교) 고등학교(계성고교) 대학교(대구카...         175
# 22  초등학교(계성초,남산초) 중학교(계성중,성명여중) 고등학교(신명고) 대학교(계명대의...         249
# 23  초등학교(경북대사범부속초,명덕초,영선초) 중학교(제일중,경북대사범부속중) 고등학교(...         111
# 24  초등학교(종로초,수창초,계성초,대성초,남산초,대구초) 중학교(계성중,성명여중) 고등...         100
#
#     KAPTD_PCNTU KAPTD_WTIMEBUS KAPTD_WTIMESUB  KAPT_DONG_CNT  KAPT_MGR_CNT  \
# 0           605           5분이내           5분이내              2             5
# 1           930           5분이내           5분이내              7             6
# 2             0           5분이내       10~15분이내              7             8
# 3          1270           5분이내           5분이내              7            14
# 4           400           5분이내        5~10분이내              6             5
# 5             0           5분이내           5분이내              2             1
# 6           181        5~10분이내           5분이내              3             3
# 7           218       10~15분이내        5~10분이내              1             4
# 8            76           5분이내        5~10분이내              1             2
# 9           798           5분이내        5~10분이내              8             6
# 10          108           5분이내        5~10분이내              1             3
# 11            0        5~10분이내       10~15분이내              3             5
# 12          475        5~10분이내           5분이내              6             6
# 13          407        5~10분이내        5~10분이내              5             5
# 14         1174           5분이내           5분이내             10             7
# 15           79        5~10분이내       15~20분이내              3             4
# 16          203           5분이내           5분이내              5             5
# 17          524           5분이내           5분이내              3             5
# 18          536           5분이내       15~20분이내              8             8
# 19           56        5~10분이내       15~20분이내              1             2
# 20          203           5분이내              -              1             2
# 21         1321        5~10분이내        5~10분이내             13             8
# 22          536           5분이내           5분이내              6             5
# 23          184        5~10분이내       10~15분이내              3             3
# 24           18           5분이내        5~10분이내              1             1
#
#     KAPTD_ECNTP KAPT_USEDATE    SUBWAY_LINE SUBWAY_STATION  \
# 0             5   2007-10-09       1호선, 2호선            반월당
# 1            14   2013-04-03            2호선           경대병원
# 2            27   1986-12-05            2호선           경대병원
# 3            16   2007-03-23            2호선          경대병원역
# 4            10   2015-11-25            2호선          대구2호선
# 5             4   1978-11-18            2호선           경대병원
# 6            11   2006-05-22            3호선             명덕
# 7             0   2014-01-21            1호선              -
# 8             2   1985-07-15            1호선             대구
# 9             0   2005-04-27            2호선            반고개
# 10            0   2014-02-07       1호선, 2호선            반월당
# 11           10   1992-06-30       2호선, 3호선             명덕
# 12           14   2008-10-28            2호선             신남
# 13           10   2008-10-28            2호선             신남
# 14           20   2014-04-30       2호선, 3호선          명덕,신남
# 15            8   1992-12-17  1호선, 2호선, 3호선          명덕,신남
# 16           12   2014-07-31            1호선           반월당역
# 17           10   2007-07-27       1호선, 2호선            반월당
# 18           20   1993-03-29       1호선, 3호선             명덕
# 19            4   1997-07-11            1호선           칠성시장
# 20            5   2009-03-05            2호선              -
# 21           24   2015-04-15            2호선              -
# 22           11   2006-10-25       2호선, 3호선             신남
# 23            0   2006-08-18            2호선           경대병원
# 24            2   1986-12-10            2호선            신남역
#
#                                      WELFARE_FACILITY
# 0                  관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 1        관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 2                          관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 3   관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 4        관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 5                               관리사무소, 어린이놀이터, 자전거보관소
# 6                          관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 7                                               관리사무소
# 8                                  관리사무소, 노인정, 자전거보관소
# 9        관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 10                                      관리사무소, 주민공동시설
# 11                                 관리사무소, 노인정, 어린이놀이터
# 12  관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소...
# 13     관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소
# 14  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 15                                 관리사무소, 노인정, 어린이놀이터
# 16  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 17                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 18                         관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 19                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 20                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 21  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 22                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 23                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 24                              관리사무소, 어린이놀이터, 자전거보관소

# %%
result.shape
# Out:
# (25, 18)

# %% [markdown]
# FEATURES:
# -   CODE_HALL: 복도형식,
# -   CODE_HEAT: 난방방식,
# -   CODE_SEC: 관리방식,
# -   CODE_STR: 건축구조,
# -   CONVENIENT_FACILITY: 편의시설,
# -   EDUCATION_FACILITY: 교육시설,
# -   KAPTD_PCNT: 주차공간(지상),
# -   KAPTD_PCNTU: 주차공간(지하),
# -   KAPTD_WTIMEBUS: 버스정류장,
# -   KAPTD_WTIMESUB: 지하철,
# -   KAPT_DONG_CNT: 동 갯수,
# -   KAPT_MGR_CNT: 일반관리인원,
# -   KAPTD_ECNTP: 엘리베이터갯수,
# -   KAPT_USEDATE: 사용승인일,
# -   SUBWAY_LINE: 지하철노선,
# -   SUBWAY_STATION: 지하철역,
# -   WELFARE_FACILITY: 부대/복리 시설

# 15  초등학교(남산초,남대구초,명덕초) 중학교(경구중,제일중,경상중) 고등학교(경북공업고...         142
# 16                                초등학교() 중학교() 고등학교()         467
# 17  초등학교(대구초,계성초) 중학교(제일중,계성중) 고등학교(경북여고,계성고) 대학교(...         554
# 18  초등학교(남산초,명덕초,남대구초,내당초) 중학교(경구중,경상중,구남중) 고등학교(경...         523
# 19  초등학교(동인초,동덕초,대구초,경북대사범부속초) 대학교(경대의과대,경대의과대보건대학...          82
# 20    초등학교(동인초,동덕초) 중학교(대구중앙중) 고등학교(중앙정보고) 대학교(경북대의대)          25
# 21  초등학교(계성초교,대구남산초교) 중학교(계성중교) 고등학교(계성고교) 대학교(대구카...         175
# 22  초등학교(계성초,남산초) 중학교(계성중,성명여중) 고등학교(신명고) 대학교(계명대의...         249
# 23  초등학교(경북대사범부속초,명덕초,영선초) 중학교(제일중,경북대사범부속중) 고등학교(...         111
# 24  초등학교(종로초,수창초,계성초,대성초,남산초,대구초) 중학교(계성중,성명여중) 고등...         100
#
#     KAPTD_PCNTU KAPTD_WTIMEBUS KAPTD_WTIMESUB  KAPT_DONG_CNT  KAPT_MGR_CNT  \
# 0           605           5분이내           5분이내              2             5
# 1           930           5분이내           5분이내              7             6
# 2             0           5분이내       10~15분이내              7             8
# 3          1270           5분이내           5분이내              7            14
# 4           400           5분이내        5~10분이내              6             5
# 5             0           5분이내           5분이내              2             1
# 6           181        5~10분이내           5분이내              3             3
# 7           218       10~15분이내        5~10분이내              1             4
# 8            76           5분이내        5~10분이내              1             2
# 9           798           5분이내        5~10분이내              8             6
# 10          108           5분이내        5~10분이내              1             3
# 11            0        5~10분이내       10~15분이내              3             5
# 12          475        5~10분이내           5분이내              6             6
# 13          407        5~10분이내        5~10분이내              5             5
# 14         1174           5분이내           5분이내             10             7
# 15           79        5~10분이내       15~20분이내              3             4
# 16          203           5분이내           5분이내              5             5
# 17          524           5분이내           5분이내              3             5
# 18          536           5분이내       15~20분이내              8             8
# 19           56        5~10분이내       15~20분이내              1             2
# 20          203           5분이내              -              1             2
# 21         1321        5~10분이내        5~10분이내             13             8
# 22          536           5분이내           5분이내              6             5
# 23          184        5~10분이내       10~15분이내              3             3
# 24           18           5분이내        5~10분이내              1             1
#
#     KAPTD_ECNTP KAPT_USEDATE    SUBWAY_LINE SUBWAY_STATION  \
# 0             5   2007-10-09       1호선, 2호선            반월당
# 1            14   2013-04-03            2호선           경대병원
# 2            27   1986-12-05            2호선           경대병원
# 3            16   2007-03-23            2호선          경대병원역
# 4            10   2015-11-25            2호선          대구2호선
# 5             4   1978-11-18            2호선           경대병원
# 6            11   2006-05-22            3호선             명덕
# 7             0   2014-01-21            1호선              -
# 8             2   1985-07-15            1호선             대구
# 9             0   2005-04-27            2호선            반고개
# 10            0   2014-02-07       1호선, 2호선            반월당
# 11           10   1992-06-30       2호선, 3호선             명덕
# 12           14   2008-10-28            2호선             신남
# 13           10   2008-10-28            2호선             신남
# 14           20   2014-04-30       2호선, 3호선          명덕,신남
# 15            8   1992-12-17  1호선, 2호선, 3호선          명덕,신남
# 16           12   2014-07-31            1호선           반월당역
# 17           10   2007-07-27       1호선, 2호선            반월당
# 18           20   1993-03-29       1호선, 3호선             명덕
# 19            4   1997-07-11            1호선           칠성시장
# 20            5   2009-03-05            2호선              -
# 21           24   2015-04-15            2호선              -
# 22           11   2006-10-25       2호선, 3호선             신남
# 23            0   2006-08-18            2호선           경대병원
# 24            2   1986-12-10            2호선            신남역
#
#                                      WELFARE_FACILITY
# 0                  관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 1        관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 2                          관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 3   관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 4        관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 5                               관리사무소, 어린이놀이터, 자전거보관소
# 6                          관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 7                                               관리사무소
# 8                                  관리사무소, 노인정, 자전거보관소
# 9        관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 10                                      관리사무소, 주민공동시설
# 11                                 관리사무소, 노인정, 어린이놀이터
# 12  관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소...
# 13     관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소
# 14  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 15                                 관리사무소, 노인정, 어린이놀이터
# 16  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 17                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 18                         관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 19                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 20                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 21  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 22                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 23                 관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 24                              관리사무소, 어린이놀이터, 자전거보관소

# %%
# left merge
# 표 merge에 대해 잘 설명된 곳 참조하세요: 'https://chrisalbon.com/python/pandas_join_merge_dataframe.html'
final_df = pd.merge(df, result, how='left', on='아파트코드')
final_df
# Out:
#        거래금액  건축년도     년    법정동         아파트  월      일    전용면적      지번   지역코드  \
# 0     14500  2007  2007  동인동1가      삼승슈퍼타워  8   1~10   83.50     362  27110
# 1     15300  2007  2007  동인동1가      삼승슈퍼타워  8  21~31   83.50     362  27110
# 2     16920  2007  2007  동인동1가      삼승슈퍼타워  8  21~31   83.50     362  27110
# 3     16000  2006  2007    봉산동       봉산뜨란채  8   1~10   75.95     110  27110
# 4      9200  1975  2007     수동        희도맨션  8   1~10  101.26     101  27110
# 5      5800  1985  2007  태평로1가      라이프아파트  8   1~10   54.60   1-187  27110
# 6      5500  1985  2007  태평로1가      라이프아파트  8   1~10   54.60   1-187  27110
# 7      5100  1976  2007    도원동          도원  8   1~10   38.91     3-5  27110
# 8     12500  2007  2007    동산동      석우리치타운  8   1~10   81.90     5-2  27110
# 9     12500  2007  2007    동산동      석우리치타운  8  11~20   81.90     5-2  27110
# 10    43000  2006  2007    대신동    태왕아너스스카이  8  21~31  191.39   305-1  27110
# 11     9500  1985  2007    대신동          동서  8  21~31   65.06    1450  27110
# 12     7700  1984  2007    달성동        금오맨션  8  21~31   78.00   118-3  27110
# 13    25000  1993  2007    남산동      보성황실타운  8   1~10  163.72  2466-1  27110
# 14     4050  1992  2007    남산동       까치아파트  8   1~10   33.06  2482-1  27110
# 15     8850  1992  2007    남산동      보성송림맨션  8  11~20   59.99    2434  27110
# 6916  63000  2007  2017    대봉동      센트로팰리스  8   1~10  179.46   60-10  27110
# 6917  64500  2007  2017    대봉동      센트로팰리스  8   1~10  179.46   60-10  27110
# 6918  28800  2006  2017    대봉동    대봉화성파크드림  8  11~20   79.74  152-24  27110
# 6919  34700  2015  2017    대봉동  대봉태왕아너스아파트  8  11~20   59.97     758  27110
# 6920  54500  2007  2017    대봉동      센트로팰리스  8  11~20  153.05   60-10  27110
# 6921  57800  2007  2017    대봉동      센트로팰리스  8  21~31  153.05   60-10  27110
# 6922  33700  2006  2017    대봉동    대봉화성파크드림  8  21~31   84.05  152-24  27110
# 6923  40400  2007  2017    대봉동      센트로팰리스  8  21~31   80.74   60-10  27110
# 6924  35300  1978  2017    대봉동      대봉청구타운  8  21~31  123.31    55-3  27110
# 6925  44500  2007  2017    대봉동      센트로팰리스  8  21~31   80.74   60-10  27110
#
#                             ...                          KAPTD_PCNTU  \
# 0                           ...                                  NaN
# 1                           ...                                  NaN
# 2                           ...                                  NaN
# 3                           ...                                184.0
# 4                           ...                                  NaN
# 5                           ...                                 76.0
# 6                           ...                                 76.0
# 7                           ...                                  NaN
# 8                           ...                                  NaN
# 9                           ...                                  NaN
# 10                          ...                                536.0
# 11                          ...                                  NaN
# 12                          ...                                  NaN
# 13                          ...                                536.0
# 14                          ...                                  0.0
# 15                          ...                                 79.0
# 16                          ...                                536.0
# 17                          ...                                536.0
# 18                          ...                                 79.0
# 19                          ...                                  NaN
# 20                          ...                                  NaN
# 21                          ...                                  NaN
# 22                          ...                                  0.0
# 23                          ...                                  0.0
# 24                          ...                               1270.0
# 25                          ...                                  NaN
# 26                          ...                                  NaN
# 27                          ...                                  NaN
# 28                          ...                                 76.0
# 29                          ...                                 18.0
# ...                         ...                                  ...
# 6896                        ...                                536.0
# 6897                        ...                                536.0
# 6898                        ...                                798.0
# 6899                        ...                                798.0
# 6900                        ...                                  0.0
# 6901                        ...                                108.0
# 6902                        ...                               1174.0
# 6903                        ...                                475.0
# 6904                        ...                                536.0
# 6905                        ...                                536.0
# 6906                        ...                                  0.0
# 6907                        ...                               1270.0
# 6908                        ...                                  0.0
# 6909                        ...                                400.0
# 6910                        ...                                181.0
# 6911                        ...                               1270.0
# 6912                        ...                                400.0
# 6913                        ...                               1270.0
# 6914                        ...                                  0.0
# 6915                        ...                                  0.0
# 6916                        ...                               1270.0
# 6917                        ...                               1270.0
# 6918                        ...                                181.0
# 6919                        ...                                400.0
# 6920                        ...                               1270.0
# 6921                        ...                               1270.0
# 6922                        ...                                181.0
# 6923                        ...                               1270.0
# 6924                        ...                                  0.0
# 6925                        ...                               1270.0
#
#       KAPTD_WTIMEBUS KAPTD_WTIMESUB KAPT_DONG_CNT KAPT_MGR_CNT KAPTD_ECNTP  \
# 0                NaN            NaN           NaN          NaN         NaN
# 1                NaN            NaN           NaN          NaN         NaN
# 2                NaN            NaN           NaN          NaN         NaN
# 3            5~10분이내       10~15분이내           3.0          3.0         0.0
# 4                NaN            NaN           NaN          NaN         NaN
# 5               5분이내        5~10분이내           1.0          2.0         2.0
# 6               5분이내        5~10분이내           1.0          2.0         2.0
# 7                NaN            NaN           NaN          NaN         NaN
# 8                NaN            NaN           NaN          NaN         NaN
# 9                NaN            NaN           NaN          NaN         NaN
# 10              5분이내           5분이내           6.0          5.0        11.0
# 11               NaN            NaN           NaN          NaN         NaN
# 12               NaN            NaN           NaN          NaN         NaN
# 13              5분이내       15~20분이내           8.0          8.0        20.0
# 14           5~10분이내       10~15분이내           3.0          5.0        10.0
# 15           5~10분이내       15~20분이내           3.0          4.0         8.0
# 16              5분이내       15~20분이내           8.0          8.0        20.0
# 17              5분이내       15~20분이내           8.0          8.0        20.0
# 18           5~10분이내       15~20분이내           3.0          4.0         8.0
# 19               NaN            NaN           NaN          NaN         NaN
# 20               NaN            NaN           NaN          NaN         NaN
# 21               NaN            NaN           NaN          NaN         NaN
# 22              5분이내       10~15분이내           7.0          8.0        27.0
# 23              5분이내       10~15분이내           7.0          8.0        27.0
# 24              5분이내           5분이내           7.0         14.0        16.0
# 25               NaN            NaN           NaN          NaN         NaN
# 26               NaN            NaN           NaN          NaN         NaN
# 27               NaN            NaN           NaN          NaN         NaN
# 28              5분이내        5~10분이내           1.0          2.0         2.0
# 29              5분이내        5~10분이내           1.0          1.0         2.0
# ...              ...            ...           ...          ...         ...
# 6896            5분이내       15~20분이내           8.0          8.0        20.0
# 6897            5분이내       15~20분이내           8.0          8.0        20.0
# 6898            5분이내        5~10분이내           8.0          6.0         0.0
# 6899            5분이내        5~10분이내           8.0          6.0         0.0
# 6900         5~10분이내       10~15분이내           3.0          5.0        10.0
# 6901            5분이내        5~10분이내           1.0          3.0         0.0
# 6902            5분이내           5분이내          10.0          7.0        20.0
# 6903         5~10분이내           5분이내           6.0          6.0        14.0
# 6904            5분이내       15~20분이내           8.0          8.0        20.0
# 6905            5분이내       15~20분이내           8.0          8.0        20.0
# 6906            5분이내           5분이내           2.0          1.0         4.0
# 6907            5분이내           5분이내           7.0         14.0        16.0
# 6908            5분이내           5분이내           2.0          1.0         4.0
# 6909            5분이내        5~10분이내           6.0          5.0        10.0
# 6910         5~10분이내           5분이내           3.0          3.0        11.0
# 6911            5분이내           5분이내           7.0         14.0        16.0
# 6912            5분이내        5~10분이내           6.0          5.0        10.0
# 6913            5분이내           5분이내           7.0         14.0        16.0
# 6914            5분이내       10~15분이내           7.0          8.0        27.0
# 6915            5분이내       10~15분이내           7.0          8.0        27.0
# 6916            5분이내           5분이내           7.0         14.0        16.0
# 6917            5분이내           5분이내           7.0         14.0        16.0
# 6918         5~10분이내           5분이내           3.0          3.0        11.0
# 6919            5분이내        5~10분이내           6.0          5.0        10.0
# 6920            5분이내           5분이내           7.0         14.0        16.0
# 6921            5분이내           5분이내           7.0         14.0        16.0
# 6922         5~10분이내           5분이내           3.0          3.0        11.0
# 6923            5분이내           5분이내           7.0         14.0        16.0
# 6924            5분이내           5분이내           2.0          1.0         4.0
# 6925            5분이내           5분이내           7.0         14.0        16.0
#
#      KAPT_USEDATE    SUBWAY_LINE SUBWAY_STATION  \
# 0             NaN            NaN            NaN
# 1             NaN            NaN            NaN
# 2             NaN            NaN            NaN
# 3      2006-08-18            2호선           경대병원
# 4             NaN            NaN            NaN
# 5      1985-07-15            1호선             대구
# 6      1985-07-15            1호선             대구
# 7             NaN            NaN            NaN
# 8             NaN            NaN            NaN
# 9             NaN            NaN            NaN
# 10     2006-10-25       2호선, 3호선             신남
# 11            NaN            NaN            NaN
# 12            NaN            NaN            NaN
# 13     1993-03-29       1호선, 3호선             명덕
# 14     1992-06-30       2호선, 3호선             명덕
# 15     1992-12-17  1호선, 2호선, 3호선          명덕,신남
# 16     1993-03-29       1호선, 3호선             명덕
# 17     1993-03-29       1호선, 3호선             명덕
# 18     1992-12-17  1호선, 2호선, 3호선          명덕,신남
# 19            NaN            NaN            NaN
# 20            NaN            NaN            NaN
# 21            NaN            NaN            NaN
# 22     1986-12-05            2호선           경대병원
# 23     1986-12-05            2호선           경대병원
# 24     2007-03-23            2호선          경대병원역
# 25            NaN            NaN            NaN
# 26            NaN            NaN            NaN
# 27            NaN            NaN            NaN
# 28     1985-07-15            1호선             대구
# 29     1986-12-10            2호선            신남역
# ...           ...            ...            ...
# 6896   1993-03-29       1호선, 3호선             명덕
# 6897   1993-03-29       1호선, 3호선             명덕
# 6898   2005-04-27            2호선            반고개
# 6899   2005-04-27            2호선            반고개
# 6900   1992-06-30       2호선, 3호선             명덕
# 6901   2014-02-07       1호선, 2호선            반월당
# 6902   2014-04-30       2호선, 3호선          명덕,신남
# 6903   2008-10-28            2호선             신남
# 6904   1993-03-29       1호선, 3호선             명덕
# 6905   1993-03-29       1호선, 3호선             명덕
# 6906   1978-11-18            2호선           경대병원
# 6907   2007-03-23            2호선          경대병원역
# 6908   1978-11-18            2호선           경대병원
# 6909   2015-11-25            2호선          대구2호선
# 6910   2006-05-22            3호선             명덕
# 6911   2007-03-23            2호선          경대병원역
# 6912   2015-11-25            2호선          대구2호선
# 6913   2007-03-23            2호선          경대병원역
# 6914   1986-12-05            2호선           경대병원
# 6915   1986-12-05            2호선           경대병원
# 6916   2007-03-23            2호선          경대병원역
# 6917   2007-03-23            2호선          경대병원역
# 6918   2006-05-22            3호선             명덕
# 6919   2015-11-25            2호선          대구2호선
# 6920   2007-03-23            2호선          경대병원역
# 6921   2007-03-23            2호선          경대병원역
# 6922   2006-05-22            3호선             명덕
# 6923   2007-03-23            2호선          경대병원역
# 6924   1978-11-18            2호선           경대병원
# 6925   2007-03-23            2호선          경대병원역
#
#                                        WELFARE_FACILITY
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                    관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 4                                                   NaN
# 5                                    관리사무소, 노인정, 자전거보관소
# 6                                    관리사무소, 노인정, 자전거보관소
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                   관리사무소, 노인정, 주민공동시설, 어린이놀이터, 자전거보관소
# 11                                                  NaN
# 12                                                  NaN
# 13                           관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 14                                   관리사무소, 노인정, 어린이놀이터
# 15                                   관리사무소, 노인정, 어린이놀이터
# 16                           관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 17                           관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 18                                   관리사무소, 노인정, 어린이놀이터
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                           관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 23                           관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 24    관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                   관리사무소, 노인정, 자전거보관소
# 29                                관리사무소, 어린이놀이터, 자전거보관소
# ...                                                 ...
# 6896                         관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 6897                         관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 6898       관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 6899       관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 6900                                 관리사무소, 노인정, 어린이놀이터
# 6901                                      관리사무소, 주민공동시설
# 6902  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6903  관리사무소, 노인정, 보육시설, 주민공동시설, 어린이놀이터, 휴게시설, 자전거보관소...
# 6904                         관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 6905                         관리사무소, 노인정, 주민공동시설, 어린이놀이터
# 6906                              관리사무소, 어린이놀이터, 자전거보관소
# 6907  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6908                              관리사무소, 어린이놀이터, 자전거보관소
# 6909       관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 6910                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 6911  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6912       관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 6913  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6914                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 6915                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 6916  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6917  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6918                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 6919       관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 자전거보관소
# 6920  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6921  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6922                         관리사무소, 노인정, 어린이놀이터, 자전거보관소
# 6923  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
# 6924                              관리사무소, 어린이놀이터, 자전거보관소
# 6925  관리사무소, 노인정, 보육시설, 문고, 주민공동시설, 어린이놀이터, 휴게시설, 커뮤...
#
# [6926 rows x 30 columns]

# %%
# 열의 이름을 한국어로 바꿔줍시다
final_df.rename(columns={'년': '거래년도',
'월': '거래월',
'일': '거래일',
'CODE_HALL': '복도형식',
'CODE_HEAT': '난방방식',
'CODE_SEC': '관리방식',
'CODE_STR': '건축구조',
'CONVENIENT_FACILITY': '편의시설',
'EDUCATION_FACILITY': '교육시설',
'KAPTD_PCNT': '주차공간(지상)',
'KAPTD_PCNTU': '주차공간(지하)',
'KAPTD_WTIMEBUS': '버스정류장',
'KAPTD_WTIMESUB': '지하철',
'KAPT_DONG_CNT': '동갯수',
'KAPT_MGR_CNT': '일반관리인원',
'KAPTD_ECNTP': '엘리베이터갯수',
'KAPT_USEDATE': '사용승인일',
'SUBWAY_LINE': '지하철노선',
'SUBWAY_STATION': '지하철역',
'WELFARE_FACILITY': '부대/복리시설'}, inplace=True)

# %%
# 합쳐진 최종 데이터를 엑셀로 저장합니다.
writer = pd.ExcelWriter('data.xlsx')
final_df.to_excel(writer, 'Sheet1', index=True)
writer.save()

# %% [markdown]
# # 데이터 모으기 끝!!

# %%
final_df['아파트코드'].isnull().sum()
1035 / 6926 * 100
# Out:
# 14.943690441813457

# %% [markdown]
# 전체 데이터 : 6926개
# 세부정보가 없는 데이터 : 1035개 (15%)

# %% [markdown]
# # 참조:
# 데이터 모으기
# - http://goodvc.tistory.com/10
